# %%
import HW3

# %% [markdown]
# ### Questions a) and b)

# %%
HW3.main()

# %% [markdown]
# The density curve above shows how the density decays from its maximum at the center of the plumber's sphere.  The vertical line at 1400 represents the radius of our sphere.  Visually, it would appear that the generated model is consistent with this density curve.

# %% [markdown]
# ### The models for parts e and f are below

# %%
from IPython.display import Video

# %% [markdown]
# #### The stable model:

# %%
Video("Stable_Plum.mp4")
# Out:
# <video src="Stable_Plum.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# #### The instable sphere:

# %%
Video("Sphere.mp4")
# Out:
# <video src="Sphere.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
